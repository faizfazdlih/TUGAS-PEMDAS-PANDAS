# %%
#1  Pastikan kolom-kolomnya menyertakan nama Kabupaten/Kota, jumlah produksi sampah (dalam ton), dan tahun pencatatan

import pandas as pd

df_csv = pd.read_csv('sampah_disperkim.csv')
df_disperkim = pd.DataFrame(df_csv, columns=['nama_kabupaten_kota','jumlah_produksi_sampah','satuan','tahun'])
df_disperkim
# Out:
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# 2     KABUPATEN CIANJUR                  981.41  TON PER HARI   2015
# 3     KABUPATEN BANDUNG                 1895.94  TON PER HARI   2015
# 4       KABUPATEN GARUT                  464.74  TON PER HARI   2015
# ..                  ...                     ...           ...    ...
# 238         KOTA BEKASI                     NaN  TON PER HARI   2023
# 239          KOTA DEPOK                     NaN  TON PER HARI   2023
# 240         KOTA CIMAHI                     NaN  TON PER HARI   2023
# 241    KOTA TASIKMALAYA                     NaN  TON PER HARI   2023
# 242         KOTA BANJAR                     NaN  TON PER HARI   2023
#
# [243 rows x 4 columns]

# %%
#2  Hitunglah total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat untuk tahun tertentu

import pandas as pd

df_csv = pd.read_csv('sampah_disperkim.csv')
tahun = 2015

total = 0
for i,j in df_csv.iterrows():
    if j['tahun'] == tahun:
        total += j['jumlah_produksi_sampah']
print(f"Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun {tahun} : {total} ton")
# Out:
# Total produksi sampah di seluruh Kabupaten/Kota di Jawa Barat pada tahun 2015 : 20969.269999999997 ton

# %%
#3 Jumlahkan Data Pertahun

import pandas as pd

df_csv = pd.read_csv('sampah_disperkim.csv')
data = {}

for i, j in df_csv.iterrows():
    tahun = j['tahun']
    produksi = j['jumlah_produksi_sampah']
    if tahun in data:
        data[tahun] += produksi
    else:
        data[tahun] = produksi

for tahun,jumlah in data.items():
    print(f"Jumlah data tahun {tahun} : {jumlah} ton")
# Out:
# Jumlah data tahun 2015 : 20969.269999999997 ton
# Jumlah data tahun 2016 : 20969.269999999997 ton
# Jumlah data tahun 2017 : 20969.269999999997 ton
# Jumlah data tahun 2018 : 22772.92 ton
# Jumlah data tahun 2019 : 24490.559999999998 ton
# Jumlah data tahun 2020 : 25333.0 ton
# Jumlah data tahun 2021 : 15735.360000000002 ton
# Jumlah data tahun 2022 : nan ton
# Jumlah data tahun 2023 : nan ton

# %%
#4 Jumlahkan data per Kota/Kabupaten per tahun

import pandas as pd

df_csv = pd.read_csv('sampah_disperkim.csv')
data = {}   

for i, j in df_csv.iterrows():
    kota = j['nama_kabupaten_kota']
    tahun = j['tahun']
    jumlah = j['jumlah_produksi_sampah']
    if kota not in data:
        data[kota] = {}
    if kota not in data[kota]:
        data[kota][tahun] = 0
    data[kota][tahun] += j['jumlah_produksi_sampah']

for kota, data_kota in data.items():
    print(f'{kota} : ')
    for tahun, banyak in data_kota.items():
        print(f'Jumah data per Kota/Kabupaten {tahun} per {banyak}')
# Out:
# KABUPATEN BOGOR :
# Jumah data per Kota/Kabupaten 2015 per 1511.15
# Jumah data per Kota/Kabupaten 2016 per 1511.15
# Jumah data per Kota/Kabupaten 2017 per 1511.15
# Jumah data per Kota/Kabupaten 2018 per 1716.8
# Jumah data per Kota/Kabupaten 2019 per 2914.65
# Jumah data per Kota/Kabupaten 2020 per 2977.0
# Jumah data per Kota/Kabupaten 2021 per 971.59
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN SUKABUMI :
# Jumah data per Kota/Kabupaten 2015 per 419.01
# Jumah data per Kota/Kabupaten 2016 per 419.01
# Jumah data per Kota/Kabupaten 2017 per 419.01
# Jumah data per Kota/Kabupaten 2018 per 415.5
# Jumah data per Kota/Kabupaten 2019 per 1003.64
# Jumah data per Kota/Kabupaten 2020 per 1006.0
# Jumah data per Kota/Kabupaten 2021 per 356.02
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN CIANJUR :
# Jumah data per Kota/Kabupaten 2015 per 981.41
# Jumah data per Kota/Kabupaten 2016 per 981.41
# Jumah data per Kota/Kabupaten 2017 per 981.41
# Jumah data per Kota/Kabupaten 2018 per 965.19
# Jumah data per Kota/Kabupaten 2019 per 1115.81
# Jumah data per Kota/Kabupaten 2020 per 1117.0
# Jumah data per Kota/Kabupaten 2021 per 355.69
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN BANDUNG :
# Jumah data per Kota/Kabupaten 2015 per 1895.94
# Jumah data per Kota/Kabupaten 2016 per 1895.94
# Jumah data per Kota/Kabupaten 2017 per 1895.94
# Jumah data per Kota/Kabupaten 2018 per 2068.06
# Jumah data per Kota/Kabupaten 2019 per 1334.12
# Jumah data per Kota/Kabupaten 2020 per 1355.0
# Jumah data per Kota/Kabupaten 2021 per 1489.04
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN GARUT :
# Jumah data per Kota/Kabupaten 2015 per 464.74
# Jumah data per Kota/Kabupaten 2016 per 464.74
# Jumah data per Kota/Kabupaten 2017 per 464.74
# Jumah data per Kota/Kabupaten 2018 per 473.89
# Jumah data per Kota/Kabupaten 2019 per 1144.01
# Jumah data per Kota/Kabupaten 2020 per 1151.0
# Jumah data per Kota/Kabupaten 2021 per 321.17
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN TASIKMALAYA :
# Jumah data per Kota/Kabupaten 2015 per 464.52
# Jumah data per Kota/Kabupaten 2016 per 464.52
# Jumah data per Kota/Kabupaten 2017 per 464.52
# Jumah data per Kota/Kabupaten 2018 per 458.45
# Jumah data per Kota/Kabupaten 2019 per 753.06
# Jumah data per Kota/Kabupaten 2020 per 754.0
# Jumah data per Kota/Kabupaten 2021 per 172.26
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN CIAMIS :
# Jumah data per Kota/Kabupaten 2015 per 260.91
# Jumah data per Kota/Kabupaten 2016 per 260.91
# Jumah data per Kota/Kabupaten 2017 per 260.91
# Jumah data per Kota/Kabupaten 2018 per 263.01
# Jumah data per Kota/Kabupaten 2019 per 560.57
# Jumah data per Kota/Kabupaten 2020 per 564.0
# Jumah data per Kota/Kabupaten 2021 per 159.41
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN KUNINGAN :
# Jumah data per Kota/Kabupaten 2015 per 251.7
# Jumah data per Kota/Kabupaten 2016 per 251.7
# Jumah data per Kota/Kabupaten 2017 per 251.7
# Jumah data per Kota/Kabupaten 2018 per 248.52
# Jumah data per Kota/Kabupaten 2019 per 537.25
# Jumah data per Kota/Kabupaten 2020 per 540.0
# Jumah data per Kota/Kabupaten 2021 per 405.76
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN CIREBON :
# Jumah data per Kota/Kabupaten 2015 per 465.75
# Jumah data per Kota/Kabupaten 2016 per 465.75
# Jumah data per Kota/Kabupaten 2017 per 465.75
# Jumah data per Kota/Kabupaten 2018 per 466.25
# Jumah data per Kota/Kabupaten 2019 per 3.15
# Jumah data per Kota/Kabupaten 2020 per 1096.0
# Jumah data per Kota/Kabupaten 2021 per 242.52
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN MAJALENGKA :
# Jumah data per Kota/Kabupaten 2015 per 254.63
# Jumah data per Kota/Kabupaten 2016 per 254.63
# Jumah data per Kota/Kabupaten 2017 per 254.63
# Jumah data per Kota/Kabupaten 2018 per 249.26
# Jumah data per Kota/Kabupaten 2019 per 515.7
# Jumah data per Kota/Kabupaten 2020 per 518.0
# Jumah data per Kota/Kabupaten 2021 per 546.54
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN SUMEDANG :
# Jumah data per Kota/Kabupaten 2015 per 237.96
# Jumah data per Kota/Kabupaten 2016 per 237.96
# Jumah data per Kota/Kabupaten 2017 per 237.96
# Jumah data per Kota/Kabupaten 2018 per 236.12
# Jumah data per Kota/Kabupaten 2019 per 436.96
# Jumah data per Kota/Kabupaten 2020 per 438.0
# Jumah data per Kota/Kabupaten 2021 per 707.75
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN INDRAMAYU :
# Jumah data per Kota/Kabupaten 2015 per 613.18
# Jumah data per Kota/Kabupaten 2016 per 613.18
# Jumah data per Kota/Kabupaten 2017 per 613.18
# Jumah data per Kota/Kabupaten 2018 per 603.11
# Jumah data per Kota/Kabupaten 2019 per 1071.05
# Jumah data per Kota/Kabupaten 2020 per 1077.0
# Jumah data per Kota/Kabupaten 2021 per 792.48
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN SUBANG :
# Jumah data per Kota/Kabupaten 2015 per 487.26
# Jumah data per Kota/Kabupaten 2016 per 487.26
# Jumah data per Kota/Kabupaten 2017 per 487.26
# Jumah data per Kota/Kabupaten 2018 per 498.7
# Jumah data per Kota/Kabupaten 2019 per 1012.45
# Jumah data per Kota/Kabupaten 2020 per 1023.0
# Jumah data per Kota/Kabupaten 2021 per 739.6
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN PURWAKARTA :
# Jumah data per Kota/Kabupaten 2015 per 308.96
# Jumah data per Kota/Kabupaten 2016 per 308.96
# Jumah data per Kota/Kabupaten 2017 per 308.96
# Jumah data per Kota/Kabupaten 2018 per 323.87
# Jumah data per Kota/Kabupaten 2019 per 384.43
# Jumah data per Kota/Kabupaten 2020 per 388.0
# Jumah data per Kota/Kabupaten 2021 per 239.72
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN KARAWANG :
# Jumah data per Kota/Kabupaten 2015 per 869.86
# Jumah data per Kota/Kabupaten 2016 per 869.86
# Jumah data per Kota/Kabupaten 2017 per 869.86
# Jumah data per Kota/Kabupaten 2018 per 896.85
# Jumah data per Kota/Kabupaten 2019 per 934.4
# Jumah data per Kota/Kabupaten 2020 per 942.0
# Jumah data per Kota/Kabupaten 2021 per 614.61
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN BEKASI :
# Jumah data per Kota/Kabupaten 2015 per 1228.6
# Jumah data per Kota/Kabupaten 2016 per 1228.6
# Jumah data per Kota/Kabupaten 2017 per 1228.6
# Jumah data per Kota/Kabupaten 2018 per 1600.71
# Jumah data per Kota/Kabupaten 2019 per 2590.0
# Jumah data per Kota/Kabupaten 2020 per 2258.0
# Jumah data per Kota/Kabupaten 2021 per 1193.76
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN BANDUNG BARAT :
# Jumah data per Kota/Kabupaten 2015 per 616.08
# Jumah data per Kota/Kabupaten 2016 per 616.08
# Jumah data per Kota/Kabupaten 2017 per 616.08
# Jumah data per Kota/Kabupaten 2018 per 663.54
# Jumah data per Kota/Kabupaten 2019 per 1124.5
# Jumah data per Kota/Kabupaten 2020 per 1135.0
# Jumah data per Kota/Kabupaten 2021 per 201.09
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KABUPATEN PANGANDARAN :
# Jumah data per Kota/Kabupaten 2015 per 185.83
# Jumah data per Kota/Kabupaten 2016 per 185.83
# Jumah data per Kota/Kabupaten 2017 per 185.83
# Jumah data per Kota/Kabupaten 2018 per 171.21
# Jumah data per Kota/Kabupaten 2019 per 250.23
# Jumah data per Kota/Kabupaten 2020 per 252.0
# Jumah data per Kota/Kabupaten 2021 per 46.62
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA BOGOR :
# Jumah data per Kota/Kabupaten 2015 per 991.93
# Jumah data per Kota/Kabupaten 2016 per 991.93
# Jumah data per Kota/Kabupaten 2017 per 991.93
# Jumah data per Kota/Kabupaten 2018 per 1069.41
# Jumah data per Kota/Kabupaten 2019 per 620.55
# Jumah data per Kota/Kabupaten 2020 per 567.0
# Jumah data per Kota/Kabupaten 2021 per 719.72
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA SUKABUMI :
# Jumah data per Kota/Kabupaten 2015 per 309.91
# Jumah data per Kota/Kabupaten 2016 per 309.91
# Jumah data per Kota/Kabupaten 2017 per 309.91
# Jumah data per Kota/Kabupaten 2018 per 318.12
# Jumah data per Kota/Kabupaten 2019 per 172.82
# Jumah data per Kota/Kabupaten 2020 per 181.0
# Jumah data per Kota/Kabupaten 2021 per 232.06
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA BANDUNG :
# Jumah data per Kota/Kabupaten 2015 per 2448.63
# Jumah data per Kota/Kabupaten 2016 per 2448.63
# Jumah data per Kota/Kabupaten 2017 per 2448.63
# Jumah data per Kota/Kabupaten 2018 per 2441.12
# Jumah data per Kota/Kabupaten 2019 per 1575.73
# Jumah data per Kota/Kabupaten 2020 per 1630.0
# Jumah data per Kota/Kabupaten 2021 per 1529.04
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA CIREBON :
# Jumah data per Kota/Kabupaten 2015 per 304.15
# Jumah data per Kota/Kabupaten 2016 per 304.15
# Jumah data per Kota/Kabupaten 2017 per 304.15
# Jumah data per Kota/Kabupaten 2018 per 308.37
# Jumah data per Kota/Kabupaten 2019 per 245.0
# Jumah data per Kota/Kabupaten 2020 per 192.0
# Jumah data per Kota/Kabupaten 2021 per 229.75
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA BEKASI :
# Jumah data per Kota/Kabupaten 2015 per 2387.08
# Jumah data per Kota/Kabupaten 2016 per 2387.08
# Jumah data per Kota/Kabupaten 2017 per 2387.08
# Jumah data per Kota/Kabupaten 2018 per 2858.6
# Jumah data per Kota/Kabupaten 2019 per 2060.7
# Jumah data per Kota/Kabupaten 2020 per 1923.0
# Jumah data per Kota/Kabupaten 2021 per 1500.77
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA DEPOK :
# Jumah data per Kota/Kabupaten 2015 per 1844.3
# Jumah data per Kota/Kabupaten 2016 per 1844.3
# Jumah data per Kota/Kabupaten 2017 per 1844.3
# Jumah data per Kota/Kabupaten 2018 per 2272.07
# Jumah data per Kota/Kabupaten 2019 per 1469.77
# Jumah data per Kota/Kabupaten 2020 per 1516.0
# Jumah data per Kota/Kabupaten 2021 per 1418.87
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA CIMAHI :
# Jumah data per Kota/Kabupaten 2015 per 563.21
# Jumah data per Kota/Kabupaten 2016 per 563.21
# Jumah data per Kota/Kabupaten 2017 per 563.21
# Jumah data per Kota/Kabupaten 2018 per 592.62
# Jumah data per Kota/Kabupaten 2019 per 267.74
# Jumah data per Kota/Kabupaten 2020 per 369.0
# Jumah data per Kota/Kabupaten 2021 per 193.36
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA TASIKMALAYA :
# Jumah data per Kota/Kabupaten 2015 per 472.36
# Jumah data per Kota/Kabupaten 2016 per 472.36
# Jumah data per Kota/Kabupaten 2017 per 472.36
# Jumah data per Kota/Kabupaten 2018 per 465.23
# Jumah data per Kota/Kabupaten 2019 per 291.6
# Jumah data per Kota/Kabupaten 2020 per 285.0
# Jumah data per Kota/Kabupaten 2021 per 295.87
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
# KOTA BANJAR :
# Jumah data per Kota/Kabupaten 2015 per 130.21
# Jumah data per Kota/Kabupaten 2016 per 130.21
# Jumah data per Kota/Kabupaten 2017 per 130.21
# Jumah data per Kota/Kabupaten 2018 per 128.34
# Jumah data per Kota/Kabupaten 2019 per 100.67
# Jumah data per Kota/Kabupaten 2020 per 79.0
# Jumah data per Kota/Kabupaten 2021 per 60.29
# Jumah data per Kota/Kabupaten 2022 per nan
# Jumah data per Kota/Kabupaten 2023 per nan
